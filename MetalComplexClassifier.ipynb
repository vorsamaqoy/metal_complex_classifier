# %%
import decisionanalyzer as dan
from decisionanalyzer import *

# %% [markdown]
# For the code to work, the input dataset must be in the form of the example given:
# - Dataframe pandas with features.
# - A column for the binary membership classes, named "activity"
# - the molecular SMILES as a string
# - The last column is not strictly necessary.

# %%
#imports the training and validation set already divided and with the descriptors already calculated 
train_dtf = pd.read_csv("./PCA_descr/train_final_UV.csv", index_col=0)
test_dtf = pd.read_csv("./PCA_descr/test_final_UV.csv", index_col=0)
train_dtf
# Out:
#       T(N..N)  T(N..O)  T(N..S)  T(N..P)  T(N..F)  T(N..Cl)  T(N..Br)  \
# 966        12        0        0        0      272         0         0
# 554        92        0      138        0        0         0         0
# 2122       18      126       60        0        0         0         0
# 192        54        0        0        0      156        44         0
# 679        88        0        0        0      288         0         0
# ...       ...      ...      ...      ...      ...       ...       ...
# 3778        0        0        2        0        0         4         0
# 3235        0        0        0        0        0         0         0
# 3270       20       31        0        0        0         0         0
# 3434       26      108        0       56        0         0         0
# 3000        0        0        0        0        0         0         0
#
#       T(N..I)  T(O..O)  T(O..S)  ...  F10(O-Cl)  F10(O-X)  F10(S-F)  F10(P-F)  \
# 966         0        0        0  ...          0         0         0         0
# 554         0        0        0  ...          0         0         0         0
# 2122        0      150      228  ...          0         0         0         0
# 192         0        0        0  ...          0         0         0         0
# 679         0        0        0  ...          0         0         0         0
# ...       ...      ...      ...  ...        ...       ...       ...       ...
# 3778        0        0        0  ...          0         0         0         0
# 3235        0      760        0  ...          0         0         0         0
# 3270        0        6        0  ...          0         0         0         0
# 3434        0      116        0  ...          0         0         0         0
# 3000        0        0        0  ...          0         0         0         0
#
#       F10(P-X)  F10(F-F)  F10(F-X)  activity  \
# 966          0         0         0         1
# 554          0         0         0         1
# 2122         0         0         0         1
# 192          0         0         0         1
# 679          0         9         0         1
# ...        ...       ...       ...       ...
# 3778         0         0         0         0
# 3235         0         0         0         0
# 3270         0         0         0         0
# 3434         0         0         0         0
# 3000         0         0         0         0
#
#                                                  SMILES   UV
# 966   FC1=C(F)C(F)=C(C(F)=C1F)C1=C2C=CC3=[N]2[Pt++]2...  541
# 554   CN(C)C1=CC=C(C=C1)C1=CC(C2=CC=C(C=C2)C2=CC=CC3...  693
# 2122  [H][C@]1(CCCN1C1=[S][Ru+3]234([S-]1)[S-]C(=[S]...  575
# 192   C1(F)=C2[C-]3=C(C4=CC(C(C)(C)C)=CC=[N]4[Ir+3]3...  520
# 679   FC(F)(F)C1=NN2C(=C1)C1=[N](C=NC=C1)[Pt]21N2N=C...  501
# ...                                                 ...  ...
# 3778             C[S]1CC2=CC=CC=[N]2[Pt++]1([Cl-])[Cl-]  291
# 3235  O[P@@]1([O-])O[P@](O)([O-])[Pt+3]234([Br-])[P@...  370
# 3270  CC(C)C1=CC=CC(C(C)C)=C1N1C2=CC=CC=C2[N]2=C1C1=...  378
# 3434  CCCC[P](CCCC)(CCCC)[Pt++]([C-]#CC1=CC=C(C=C1)C...  395
# 3000  C1=CC=C(C=C1)C#[C-][Pt++]([C-]#CC1=CC=C(C=C1)C...  373
#
# [3712 rows x 390 columns]

# %% [markdown]
# The models used in this case are XGBClassifier and DecisionTreeClassifier. The hyperparameters set were chosen by Grid Search.
# Further details can be found in the reference article.

# %%
model_XGB = XGBClassifier(random_state=42,n_estimators= 400,max_depth=8, learning_rate=0.31)
model_DTC = DecisionTreeClassifier(random_state=42,max_depth=20,
                                   min_samples_split=2,min_samples_leaf=1,
                                   class_weight='balanced')
model_DTC_inst = [('DecisionTreeClassifier', model_DTC)]
model_XGB_inst = [('XGBClassifier', model_XGB)]

# %% [markdown]
# Further details on how the features importances were determined can be found in the referenced article.

# %%
feature_importance_df_sorted = pd.read_csv("./PCA_descr/feat_importance_final.csv",index_col=0)
feature_importance_df_sorted
# Out:
#        Feature  Importance
# 39    B01(C-X)    0.031573
# 116   F02(C-N)    0.011746
# 156   F03(C-X)    0.010668
# 123   F02(C-X)    0.010237
# 93    F01(C-C)    0.008190
# ..         ...         ...
# 249   F06(C-X)   -0.003341
# 77    B07(C-X)   -0.003341
# 51    B02(N-X)   -0.003341
# 129  F02(N-Cl)   -0.003556
# 152  F03(C-Cl)   -0.003879
#
# [387 rows x 2 columns]

# %% [markdown]
# Running this code determines the evaluation metrics for both models, on the training set, with SkFoldCV (K = 5, 10, 15). The number of most important Features to be used for both models was determined with Recursive Features Elimination, as explained in the reference article.

# %%
#benchmark on the training set with SkFoldCV and k-values = 5, 10, 15
#or XGBC (49 features) and DTC (26 features)

kfold_results = []

k_values = [5, 10, 15]

for model_name, model_inst, top_features in [
    ("XGBClassifier", model_XGB_inst, feature_importance_df_sorted.Feature.head(49)),
    ("DecisionTreeClassifier", model_DTC_inst, feature_importance_df_sorted.Feature.head(26))
]:
    for k in k_values:
        fold_results = train_models_classification(model_inst, train_dtf[top_features], train_dtf.activity, kfold_splits=k)
        fold_results['Model'] = model_name
        fold_results['k'] = k

        kfold_results.append(fold_results)

kfold_results_df = pd.concat(kfold_results, ignore_index=True)

cols = ['Model', 'k'] + [col for col in kfold_results_df.columns if col not in ['Model', 'k']]
kfold_results_df = kfold_results_df[cols]

kfold_results_df.set_index(['Model', 'k'], inplace=True)

kfold_results_df = kfold_results_df.round(2)
kfold_results_df
# Out:
#                            Accuracy  Sensitivity  Specificity  Precision    F1
# Model                  k
# XGBClassifier          5       0.91         0.90         0.91       0.90  0.90
#                        10      0.92         0.90         0.93       0.92  0.91
#                        15      0.91         0.90         0.92       0.91  0.91
# DecisionTreeClassifier 5       0.84         0.84         0.84       0.82  0.83
#                        10      0.85         0.84         0.85       0.83  0.84
#                        15      0.85         0.86         0.85       0.83  0.84

# %%
train_dtf_activity = train_dtf.copy()
train_dtf_activity = train_dtf_activity.reset_index(drop=True)

# %%
model = model_DTC
train_data = train_dtf_activity.iloc[:,:-2]
smiles_list =  train_dtf_activity.SMILES

#this is valid only for decision tree model
#model = trained model
#train_data = dataframe with all features and activity column
#smiles_list = list of smiles from dataset
#feature_importance_df_sorted = dataframe with features sorted by descending importance

helper = DecisionTreeHelper(model, train_data, smiles_list, feature_importance_df_sorted)

#run this to generate data for further analysis

helper.decision_paths(show_leafs=True)

#this code generates a dataframe indicating in which leaf node each molecule ended up

leaves_df = helper.find_leaves(return_list=True)

# this code allows you to get the list of "pure" nodes.
# "Pure nodes" means nodes that contain only molecules that are
# either all inactive or all active.
# Also, the directly connected node (via the parent node) will contain only molecules of the opposite class.
# In other words, all listed parent nodes split into two leaf nodes that contain only molecules
# that share the same class. This assures us that a node's division criterion is one
# that determines the division between active and inactive molecules.

pure_nodes = helper.find_splits(pure_node = True)

#leaf_descr gives more detailed information including the number of molecules in each leaf

leaf_descr = helper.describe(pure_nodes)
# Out:
# Node 692 is connected to node 693 by the common node 691
# Node 692 has 3 active compound(s)
# Node 691 has 1 inactive compound(s)
# ----------
# Node 700 is connected to node 701 by the common node 699
# Node 700 has 2 active compound(s)
# Node 699 has 1 inactive compound(s)
# ----------
# Node 703 is connected to node 704 by the common node 702
# Node 703 has 1 active compound(s)
# Node 702 has 1 inactive compound(s)
# ----------
# Node 713 is connected to node 714 by the common node 712
# Node 713 has 2 active compound(s)
# Node 712 has 3 inactive compound(s)
# ----------
# Node 719 is connected to node 720 by the common node 718
# Node 719 has 1 active compound(s)
# Node 718 has 8 inactive compound(s)
# ----------
# Node 736 is connected to node 737 by the common node 735
# Node 736 has 1 active compound(s)
# Node 735 has 1 inactive compound(s)
# ----------
# Node 781 is connected to node 782 by the common node 780
# Node 781 has 15 active compound(s)
# Node 780 has 1 inactive compound(s)
# ----------
# Node 679 is connected to node 680 by the common node 678
# Node 679 has 11 active compound(s)
# Node 678 has 1 inactive compound(s)
# ----------
# Node 598 is connected to node 599 by the common node 597
# Node 598 has 4 active compound(s)
# Node 597 has 1 inactive compound(s)
# ----------
# Node 538 is connected to node 539 by the common node 537
# Node 538 has 4 active compound(s)
# Node 537 has 1 inactive compound(s)
# ----------
# Node 548 is connected to node 549 by the common node 547
# Node 548 has 2 active compound(s)
# Node 547 has 1 inactive compound(s)
# ----------
# Node 578 is connected to node 579 by the common node 577
# Node 578 has 1 active compound(s)
# Node 577 has 1 inactive compound(s)
# ----------
# Node 606 is connected to node 607 by the common node 605
# Node 606 has 1 active compound(s)
# Node 605 has 1 inactive compound(s)
# ----------
# Node 611 is connected to node 612 by the common node 610
# Node 611 has 13 active compound(s)
# Node 610 has 1 inactive compound(s)
# ----------
# Node 617 is connected to node 618 by the common node 616
# Node 617 has 1 active compound(s)
# Node 616 has 1 inactive compound(s)
# ----------
# Node 650 is connected to node 651 by the common node 649
# Node 650 has 1 active compound(s)
# Node 649 has 1 inactive compound(s)
# ----------
# Node 799 is connected to node 800 by the common node 798
# Node 799 has 1 active compound(s)
# Node 798 has 1 inactive compound(s)
# ----------
# Node 16 is connected to node 17 by the common node 15
# Node 16 has 1 active compound(s)
# Node 15 has 1 inactive compound(s)
# ----------
# Node 955 is connected to node 956 by the common node 954
# Node 955 has 18 active compound(s)
# Node 954 has 1 inactive compound(s)
# ----------
# Node 962 is connected to node 963 by the common node 961
# Node 962 has 3 active compound(s)
# Node 961 has 1 inactive compound(s)
# ----------
# Node 989 is connected to node 990 by the common node 988
# Node 989 has 6 active compound(s)
# Node 988 has 1 inactive compound(s)
# ----------
# Node 997 is connected to node 998 by the common node 996
# Node 997 has 7 active compound(s)
# Node 996 has 1 inactive compound(s)
# ----------
# Node 1002 is connected to node 1003 by the common node 1001
# Node 1002 has 2 active compound(s)
# Node 1001 has 1 inactive compound(s)
# ----------
# Node 1017 is connected to node 1018 by the common node 1016
# Node 1017 has 1 active compound(s)
# Node 1016 has 1 inactive compound(s)
# ----------
# Node 1059 is connected to node 1060 by the common node 1058
# Node 1059 has 1 active compound(s)
# Node 1058 has 1 inactive compound(s)
# ----------
# Node 1065 is connected to node 1066 by the common node 1064
# Node 1065 has 2 active compound(s)
# Node 1064 has 1 inactive compound(s)
# ----------
# Node 948 is connected to node 949 by the common node 947
# Node 948 has 1 active compound(s)
# Node 947 has 19 inactive compound(s)
# ----------
# Node 844 is connected to node 845 by the common node 843
# Node 844 has 4 active compound(s)
# Node 843 has 2 inactive compound(s)
# ----------
# Node 850 is connected to node 851 by the common node 849
# Node 850 has 1 active compound(s)
# Node 849 has 2 inactive compound(s)
# ----------
# Node 857 is connected to node 858 by the common node 856
# Node 857 has 1 active compound(s)
# Node 856 has 1 inactive compound(s)
# ----------
# Node 882 is connected to node 883 by the common node 881
# Node 882 has 4 active compound(s)
# Node 881 has 1 inactive compound(s)
# ----------
# Node 941 is connected to node 942 by the common node 940
# Node 941 has 1 active compound(s)
# Node 940 has 3 inactive compound(s)
# ----------
# Node 908 is connected to node 909 by the common node 907
# Node 908 has 1 active compound(s)
# Node 907 has 1 inactive compound(s)
# ----------
# Node 916 is connected to node 917 by the common node 915
# Node 916 has 1 active compound(s)
# Node 915 has 1 inactive compound(s)
# ----------
# Node 922 is connected to node 923 by the common node 921
# Node 922 has 2 active compound(s)
# Node 921 has 1 inactive compound(s)
# ----------
# Node 927 is connected to node 928 by the common node 926
# Node 927 has 11 active compound(s)
# Node 926 has 1 inactive compound(s)
# ----------
# Node 534 is connected to node 535 by the common node 533
# Node 534 has 3 active compound(s)
# Node 533 has 1 inactive compound(s)
# ----------
# Node 530 is connected to node 531 by the common node 529
# Node 530 has 4 active compound(s)
# Node 529 has 11 inactive compound(s)
# ----------
# Node 519 is connected to node 520 by the common node 518
# Node 519 has 7 active compound(s)
# Node 518 has 4 inactive compound(s)
# ----------
# Node 142 is connected to node 143 by the common node 141
# Node 142 has 1 active compound(s)
# Node 141 has 1 inactive compound(s)
# ----------
# Node 150 is connected to node 151 by the common node 149
# Node 150 has 1 active compound(s)
# Node 149 has 3 inactive compound(s)
# ----------
# Node 159 is connected to node 160 by the common node 158
# Node 159 has 17 active compound(s)
# Node 158 has 1 inactive compound(s)
# ----------
# Node 182 is connected to node 183 by the common node 181
# Node 182 has 2 active compound(s)
# Node 181 has 25 inactive compound(s)
# ----------
# Node 215 is connected to node 216 by the common node 214
# Node 215 has 2 active compound(s)
# Node 214 has 1 inactive compound(s)
# ----------
# Node 239 is connected to node 240 by the common node 238
# Node 239 has 1 active compound(s)
# Node 238 has 1 inactive compound(s)
# ----------
# Node 244 is connected to node 245 by the common node 243
# Node 244 has 2 active compound(s)
# Node 243 has 1 inactive compound(s)
# ----------
# Node 264 is connected to node 265 by the common node 263
# Node 264 has 3 active compound(s)
# Node 263 has 1 inactive compound(s)
# ----------
# Node 127 is connected to node 128 by the common node 126
# Node 127 has 1 active compound(s)
# Node 126 has 1 inactive compound(s)
# ----------
# Node 62 is connected to node 63 by the common node 61
# Node 62 has 8 active compound(s)
# Node 61 has 2 inactive compound(s)
# ----------
# Node 43 is connected to node 44 by the common node 42
# Node 43 has 2 active compound(s)
# Node 42 has 4 inactive compound(s)
# ----------
# Node 70 is connected to node 71 by the common node 69
# Node 70 has 2 active compound(s)
# Node 69 has 1 inactive compound(s)
# ----------
# Node 78 is connected to node 79 by the common node 77
# Node 78 has 4 active compound(s)
# Node 77 has 2 inactive compound(s)
# ----------
# Node 90 is connected to node 91 by the common node 89
# Node 90 has 2 active compound(s)
# Node 89 has 1 inactive compound(s)
# ----------
# Node 105 is connected to node 106 by the common node 104
# Node 105 has 1 active compound(s)
# Node 104 has 1 inactive compound(s)
# ----------
# Node 118 is connected to node 119 by the common node 117
# Node 118 has 1 active compound(s)
# Node 117 has 2 inactive compound(s)
# ----------
# Node 458 is connected to node 459 by the common node 457
# Node 458 has 6 active compound(s)
# Node 457 has 3 inactive compound(s)
# ----------
# Node 430 is connected to node 431 by the common node 429
# Node 430 has 2 active compound(s)
# Node 429 has 2 inactive compound(s)
# ----------
# Node 444 is connected to node 445 by the common node 443
# Node 444 has 1 active compound(s)
# Node 443 has 18 inactive compound(s)
# ----------
# Node 448 is connected to node 449 by the common node 447
# Node 448 has 2 active compound(s)
# Node 447 has 2 inactive compound(s)
# ----------
# Node 452 is connected to node 453 by the common node 451
# Node 452 has 1 active compound(s)
# Node 451 has 3 inactive compound(s)
# ----------
# Node 462 is connected to node 463 by the common node 461
# Node 462 has 1 active compound(s)
# Node 461 has 6 inactive compound(s)
# ----------
# Node 402 is connected to node 403 by the common node 401
# Node 402 has 2 active compound(s)
# Node 401 has 7 inactive compound(s)
# ----------
# Node 465 is connected to node 466 by the common node 464
# Node 465 has 1 active compound(s)
# Node 464 has 1 inactive compound(s)
# ----------
# Node 472 is connected to node 473 by the common node 471
# Node 472 has 2 active compound(s)
# Node 471 has 7 inactive compound(s)
# ----------
# Node 476 is connected to node 477 by the common node 475
# Node 476 has 1 active compound(s)
# Node 475 has 6 inactive compound(s)
# ----------
# Node 484 is connected to node 485 by the common node 483
# Node 484 has 1 active compound(s)
# Node 483 has 1 inactive compound(s)
# ----------
# Node 506 is connected to node 507 by the common node 505
# Node 506 has 1 active compound(s)
# Node 505 has 3 inactive compound(s)
# ----------
# Node 413 is connected to node 414 by the common node 412
# Node 413 has 1 active compound(s)
# Node 412 has 1 inactive compound(s)
# ----------
# Node 398 is connected to node 399 by the common node 397
# Node 398 has 1 active compound(s)
# Node 397 has 1 inactive compound(s)
# ----------
# Node 292 is connected to node 293 by the common node 291
# Node 292 has 1 active compound(s)
# Node 291 has 1 inactive compound(s)
# ----------
# Node 299 is connected to node 300 by the common node 298
# Node 299 has 1 active compound(s)
# Node 298 has 3 inactive compound(s)
# ----------
# Node 333 is connected to node 334 by the common node 332
# Node 333 has 1 active compound(s)
# Node 332 has 1 inactive compound(s)
# ----------
# Node 394 is connected to node 395 by the common node 393
# Node 394 has 2 active compound(s)
# Node 393 has 1 inactive compound(s)
# ----------
# Node 342 is connected to node 343 by the common node 341
# Node 342 has 11 active compound(s)
# Node 341 has 1 inactive compound(s)
# ----------
# Node 358 is connected to node 359 by the common node 357
# Node 358 has 2 active compound(s)
# Node 357 has 1 inactive compound(s)
# ----------
# Node 362 is connected to node 363 by the common node 361
# Node 362 has 2 active compound(s)
# Node 361 has 7 inactive compound(s)
# ----------
# Node 378 is connected to node 379 by the common node 377
# Node 378 has 3 active compound(s)
# Node 377 has 2 inactive compound(s)
# ----------
# Node 382 is connected to node 383 by the common node 381
# Node 382 has 3 active compound(s)
# Node 381 has 1 inactive compound(s)
# ----------

# %%
#This code is useful if you are interested in which node a particular feature corresponds to.
#Just enter the feature name in string form as the function argument.
#If you do not enter anything, the most important feature according to the model is automatically taken.
helper.find_node_by_feat()
# Out:
# Descriptor 'B01(C-X)' is the decision criteria of node(s): [780]

# %%
leaves_df
# Out:
#                                                  sample  leaf
# 0     FC1=C(F)C(F)=C(C(F)=C1F)C1=C2C=CC3=[N]2[Pt++]2...   784
# 1     CN(C)C1=CC=C(C=C1)C1=CC(C2=CC=C(C=C2)C2=CC=CC3...   784
# 2     [H][C@]1(CCCN1C1=[S][Ru+3]234([S-]1)[S-]C(=[S]...   744
# 3     C1(F)=C2[C-]3=C(C4=CC(C(C)(C)C)=CC=[N]4[Ir+3]3...  1035
# 4     FC(F)(F)C1=NN2C(=C1)C1=[N](C=NC=C1)[Pt]21N2N=C...   182
# ...                                                 ...   ...
# 3707             C[S]1CC2=CC=CC=[N]2[Pt++]1([Cl-])[Cl-]    10
# 3708  O[P@@]1([O-])O[P@](O)([O-])[Pt+3]234([Br-])[P@...    10
# 3709  CC(C)C1=CC=CC(C(C)C)=C1N1C2=CC=CC=C2[N]2=C1C1=...   990
# 3710  CCCC[P](CCCC)(CCCC)[Pt++]([C-]#CC1=CC=C(C=C1)C...   841
# 3711  C1=CC=C(C=C1)C#[C-][Pt++]([C-]#CC1=CC=C(C=C1)C...   847
#
# [3712 rows x 2 columns]

# %%
pure_nodes
# Out:
#      left_leaves  parent_leaves  right_leaves
# 0             10              9            11
# 1             16             15            17
# 2             20             19            21
# 3             23             22            24
# 4             27             26            28
# ..           ...            ...           ...
# 173         1047           1046          1048
# 174         1050           1049          1051
# 175         1059           1058          1060
# 176         1065           1064          1066
# 177         1068           1067          1069
#
# [178 rows x 3 columns]

# %%
leaf_descr.sort_values(by='leaf_count',ascending=False)
# Out:
#     leaf  leaf_conn  leaf_common  leaf_count  leaf_value  leaf_conn_count  \
# 18   955        956          954          18           1                1
# 41   159        160          158          17           1                1
# 6    781        782          780          15           1                1
# 13   611        612          610          13           1                1
# 35   927        928          926          11           1                1
# ..   ...        ...          ...         ...         ...              ...
# 47   127        128          126           1           1                1
# 24  1059       1060         1058           1           1                1
# 5    736        737          735           1           1                1
# 53   105        106          104           1           1                1
# 39   142        143          141           1           1                1
#
#     leaf_conn_value
# 18                0
# 41                0
# 6                 0
# 13                0
# 35                0
# ..              ...
# 47                0
# 24                0
# 5                 0
# 53                0
# 39                0
#
# [78 rows x 7 columns]

# %%
# Given the ID number of a node, this code provides all the nodes from which it is derived backward.
# In addition, for each node found, information regarding its division is returned.
helper.backward_search(782)
# Out:
# The nodes from which node 782 is derived are, backwards: [780, 779, 778, 774, 773, 772, 771, 765, 764, 763, 729, 728, 0]
# Below is the list of nodes resulting from the split of the listed nodes
# Node 780 is splitted in: left_child = 781, right_child = 782
# Node 779 is splitted in: left_child = 780, right_child = 783
# Node 778 is splitted in: left_child = 779, right_child = 788
# Node 774 is splitted in: left_child = 775, right_child = 778
# Node 773 is splitted in: left_child = 774, right_child = 791
# Node 772 is splitted in: left_child = 773, right_child = 796
# Node 771 is splitted in: left_child = 772, right_child = 807
# Node 765 is splitted in: left_child = 766, right_child = 771
# Node 764 is splitted in: left_child = 765, right_child = 808
# Node 763 is splitted in: left_child = 764, right_child = 811
# Node 729 is splitted in: left_child = 730, right_child = 763
# Node 728 is splitted in: left_child = 729, right_child = 828
# Node 0 is splitted in: left_child = 1, right_child = 728

# %% [markdown]
# It is observed from the above results that the most important feature is in node 780.
# This node divides into leaves 781 and 782.
# Leaf 781 contains 15 active compounds, leaf 782 contains one inactive compound.

# %%
leaves_df[leaves_df["leaf"] == 782]
# Out:
#                                                  sample  leaf
# 1770  CCCCN1C2=CC3=CC=CC=C3C=C2[N]2=C1C1=CC(=CC3=[C-...   782

# %% [markdown]
# The inactive compound, number 1770, follows these decisions within the tree.
# It can be seen at the end how the last final decision is precisely that of the most important feature B01(C-X) = 1 > 0.5
# Molecule 1770 is then selected along with the tree classification rules as a starting point for a design.
# More details in the reference article.

# %%
helper.sample_decision_path(1770)
# Out:
# Rules followed by sample number 1770:
#
# Decision node 0: F05(C-X) = 7 > 6.5
# Decision node 728: F01(C-X) = 1 <= 1.5
# Decision node 729: F03(C-N) = 24 > 7.0
# Decision node 763: F01(N-N) = 0 <= 1.5
# Decision node 764: F01(C-C) = 40 <= 112.0
# Decision node 765: F02(C-X) = 6 > 4.5
# Decision node 771: F03(C-X) = 6 <= 47.0
# Decision node 772: F07(C-P) = 0 <= 3.5
# Decision node 773: F01(C-C) = 40 <= 78.5
# Decision node 774: F02(C-N) = 16 > 2.5
# Decision node 778: T(O..O) = 0 <= 1004.0
# Decision node 779: F03(C-X) = 6 <= 6.5
# Decision node 780: B01(C-X) = 1 > 0.5
# ------------------------
# Sample 1770 ends up in node 782
# and it is classified as inactive
# ------------------------
